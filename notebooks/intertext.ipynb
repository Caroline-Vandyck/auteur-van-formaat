# %% [markdown]
# # Retrieving intertexts

# %% [markdown]
# ### Loading needed libraries

# %%
import glob
import os
from collections import Counter
from itertools import combinations, product

import numpy as np
np.random.seed(18012023)

import pandas as pd
pd.set_option('display.max_colwidth', 0)

import seaborn as sb

from sklearn.metrics import pairwise_distances
import lxml.etree
from scipy.spatial.distance import pdist, squareform
from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer

import matplotlib.pyplot as plt
import matplotlib
plt.rcParams['figure.dpi'] = 300
plt.rcParams['font.family'] = 'Arial'
from IPython.display import display

# %%
fig_dir = '../figures'
if not os.path.isdir(fig_dir):
    os.mkdir(fig_dir)

# %% [markdown]
# ### Loading data and metadata

# %%
meta_df = pd.read_excel('../data/metadata.xlsx')
meta_df = meta_df[meta_df['exclude'] != 'x']
meta_df.sample(10)
# Out:
#                                          id  \
# 204  sinte_kunera
# 63   florigout_fragm_l
# 111  lippijn
# 86   Merlijn-Maerlant
# 236  spiegel_historiael__4_velthem__fragm_l
# 154  ongeidentificeerd_fragment
# 215  spiegel_der_sonden_fragm_ge1
# 123  madelgijs_fragm_p
# 168  renout_van_montalbaen_fragm_be
# 242  tien_plaghen
#
#                                   title                author provenance  \
# 204  Sinte Kunera                        NaN                   cdrom-mnl
# 63   Florigout                           NaN                   cdrom-mnl
# 111  Lippijn                             NaN                   cdrom-mnl
# 86   Merlijn                             Jacob van Maerlant    cdrom-mnl
# 236  Spiegel historiael (P4)             Lodewijk van Velthem  cdrom-mnl
# 154  Ongeïdentificeerd fragment          NaN                   cdrom-mnl
# 215  Spiegel der sonden                  NaN                   cdrom-mnl
# 123  Madelgijs                           NaN                   cdrom-mnl
# 168  Renout van Montalbaen               NaN                   cdrom-mnl
# 242  Tien plaghen ende die tien ghebode  NaN                   cdrom-mnl
#
#     date_range      genre        subgenre exclude
# 204  1400-1500  Epiek      Heiligenleven   NaN
# 63   1375-1400  Epiek      Ridder          NaN
# 111  1400-1420  Dramatiek  NaN             NaN
# 86   1415-1435  Epiek      Arthur          NaN
# 236  1340-1360  Epiek      Historiografie  NaN
# 154  1380-1400  Epiek      Didactiek       NaN
# 215  1300-1400  Epiek      Didactiek       NaN
# 123  1375-1400  Epiek      Karel           NaN
# 168  1340-1360  Epiek      Karel           NaN
# 242  1390-1410  Epiek      Didactiek       NaN

# %%
# create pairs of the verses

def get_verse_groups(verses, size=2, intertexts=False):
    for i in range(len(verses) - (size - 1)):
        if not intertexts:
            yield ' / '.join(verses[i : i + size])
        else:
            its = Counter(verses[i : i + size])
            if None in its:
                yield None
            elif len(its) > 1:
                yield 'overlap'
            else:
                yield list(its.keys())[0]

# %%
def parse_xml(fn, rm_interpol=False):
    try:
        tree = lxml.etree.parse(fn)
    except OSError:
        print(f'- Could not load {fn}')
        return None
        
    if rm_interpol:
        for interpolation in tree.xpath("//interpolation"):
            interpolation.getparent().remove(interpolation)
        
    for line_node in tree.iterfind('//l'):
        try:
            intertext_id = line_node.attrib['intertext']
        except KeyError:
            intertext_id = None
        
        tokens_ = line_node.attrib['tokens'].split()
        lemmas_ = []
        
        lemma_tags = [l.text for l in line_node.iterfind('.//lemma')]
        pos_tags = [p.text for p in line_node.iterfind('.//pos')]
        
        for lemma, pos in zip(lemma_tags, pos_tags):
            for l, p in zip(lemma.split('+'), pos.split('+')):
                    if p == 'n(prop)':
                        lemmas_.append('n(prop)')
                    else:
                        lemmas_.append(l)
    
        yield tokens_, lemmas_, intertext_id

# %%
# create a table with the titles, tokens, lemmas and interetexts for every pair of verses

GROUP_SIZE = 2

titles, tokens, lemmas, intertexts = [], [], [], []

for title, group in tqdm(meta_df.groupby('title')):
    work_tokens, work_lemmas, work_intertexts = [], [], []
    
    for id_ in sorted(group['id']):
        for tok, lem, intertext_id in parse_xml(f'../data/xml/{id_}.xml'):
            work_tokens.append(tok)
            work_lemmas.append(lem)
            work_intertexts.append(intertext_id)
    
    verse_tokens = [' '.join(v) for v in work_tokens]
    verse_lemmas = [' '.join(v) for v in work_lemmas]

    verse_group_tokens = list(get_verse_groups(verse_tokens, size=GROUP_SIZE))
    verse_group_lemmas = list(get_verse_groups(verse_lemmas, size=GROUP_SIZE))
    verse_group_intertexts = list(get_verse_groups(work_intertexts, size=GROUP_SIZE, intertexts=True))

    tokens.extend(verse_group_tokens)
    lemmas.extend(verse_group_lemmas)
    intertexts.extend(verse_group_intertexts)
    titles.extend([title] * len(verse_group_lemmas))
# Out:
# 100%|█████████████████████████████████████████| 205/205 [00:10<00:00, 19.90it/s]

# %%
df = pd.DataFrame(zip(titles, tokens, lemmas, intertexts), columns=('title', 'tokens', 'lemmas', 'intertext'))

# %%
# add the rhyme bigrams to the verses

def tokenizer(text):
    return text.replace(' / ', ' ').lower().strip().split()

def add_rhyme_column(df):
    rhyme_words = []
    for lemmas in df['lemmas']:
        rhymes = []
        for verse in lemmas.split(' / '):
            rhymes.append(verse.strip().split()[-1])
        rhyme_words.append(' '.join(rhymes))
    df['rhyme'] = rhyme_words
    return df

# %%
df = add_rhyme_column(df)
df.head()
# Out:
#                     title  \
# 0  AB recht ende averecht
# 1  AB recht ende averecht
# 2  AB recht ende averecht
# 3  AB recht ende averecht
# 4  AB recht ende averecht
#
#                                                                           tokens  \
# 0  Aensiet dese vrouwen hoe si gaen / Besiet hoe haer tuten staen
# 1  Besiet hoe haer tuten staen / Claer dat si hen blanketten
# 2  Claer dat si hen blanketten / Die cleeder soe lanc dat si hen letten
# 3  Die cleeder soe lanc dat si hen letten / Ende sleypen hen nae al op die eerde
# 4  Ende sleypen hen nae al op die eerde / Fi diere vuylder hoverde
#
#                                                                   lemmas  \
# 0  aanzien deze vrouw hoe zij gaan / bezien hoe zij de staan
# 1  bezien hoe zij de staan / klaar dat zij zij n(prop)
# 2  klaar dat zij zij n(prop) / de kleed zo lang dat zij zij letten
# 3  de kleed zo lang dat zij zij letten / en slapen zij na al op de aarde
# 4  en slapen zij na al op de aarde / fi duur vouwer hovaardij
#
#   intertext            rhyme
# 0  None      gaan staan
# 1  None      staan n(prop)
# 2  None      n(prop) letten
# 3  None      letten aarde
# 4  None      aarde hovaardij

# %%
# thresholds

optim_vs = 7000
optim_rw = 0.1693877551020408
optim_th = 0.42202047865566794

# %%
vec = TfidfVectorizer(max_features=optim_vs, min_df=2,
                      tokenizer=tokenizer, token_pattern=None).fit(df['lemmas'])

# %% [markdown]
# ### Retrieving the nearest verses

# %%
# retrieve the most similar verses

def nearest_verses(title1, title2, base_df, vectorizer, prop_filt=2, rhyme_weight=.15):
    A = base_df[base_df['title'] == title1]
    B = base_df[base_df['title'] == title2]
    
    AX = vec.transform(A['lemmas']) + rhyme_weight * vec.transform(A['rhyme'])
    BX = vec.transform(B['lemmas']) + rhyme_weight * vec.transform(B['rhyme'])
    
    nearest = []
    for i, ax in enumerate(AX):
        distances = pairwise_distances(ax, BX, metric='cosine').flatten()
        top_i = distances.argsort()[0]
        nearest.append((A.iloc[i]['tokens'], B.iloc[top_i]['tokens'],
                        A.iloc[i]['lemmas'], B.iloc[top_i]['lemmas'],
                        A.iloc[i]['title'], B.iloc[top_i]['title'],
                        A.iloc[i]['intertext'], B.iloc[top_i]['intertext'],
                        distances[top_i]))

    nearest = pd.DataFrame(nearest,
                           columns=['tokens1', 'tokens2', 'lemmas1', 'lemmas2',
                                    'title1', 'title2', 'intertext1', 'intertext2',
                                    'distance'])

    nearest = nearest[nearest['title1'] != nearest['title2']]
    nearest = nearest[
                      (nearest['lemmas1'].str.count('n\(prop\)') < prop_filt) & \
                      (nearest['lemmas1'].str.count('n\(prop\)') < prop_filt) 
                     ]
    return nearest

# %%
nearest_df = nearest_verses('Limborch', 'Roman der Lorreinen II',
                            base_df=df, vectorizer=vec, prop_filt=2)
nearest_df = nearest_df.sort_values(by='distance')
nearest_df.to_excel('../figures/limborch_lorreinenII.xlsx')
nearest_df.head(50)
# Out:
#                                                                       tokens1  \
# 3335   Smargens doe die dach ontspranc / Entie liwerke sanc
# 6723   Smergens doe die dach ontspranc / Entie liwerke sanc
# 14997  Smargens doe de dach ontspranc / Entie liwerke sanc
# 9024   Ende seide here die macht van gode / Moet u behouden in u ere
# 2346   Die den keyser goeden dach / Ontboet tierst dat sine sach
# 17189  Ic ligghe hier al miin leven lanc / Of ic hebs minen wille
# 4429   Nu es die ridder in sorgen groet / Ende in anxste van der doet
# 15115  Nu laet ic van hem bliven / Ende willu vort bescriven
# 14175  Gheseit heeft behagedem wale / Hi seide bi Mamet u tale
# 482    Ende te vertellen alle die zake / Hoe si gheweest hadde te onghemake
# 13455  Doe die keyser dat verstoet / Wert hi blide in sinen moet
# 21439  Oec bat hem die ghelike / Die keyser van den Roemscen rike
# 8559   Reden si hem ten gemoete / Dat ontmoet was onsoete
# 10795  In sconinx Therus lant / Ende stichten roef ende brant
# 14137  Ic ligghe hier al miin leven lanc / Of ic winse an haren danc
# 3415   Doe miin her Heinriic dat verstoet / Wert hi blide in sinen moet
# 6785   Nichia die dat verstoet / Wert droeve in haren moet
# 17189  ik en hebben van hij mijn wil / ik liggen hier al mijn leven lang
# 4429   die nu zijn in angst groot / en in zorg van de dood
# 15115  nu ik laten hier van zij blijven / en willen voorts beschrijven
# 14175  n(prop) zeggen gij zeggen wel / ik behagen wel uw taal
# 482    en vertellen deze zaak / en hoe n(prop) zijn ongemak te
# 13455  toen de koning dat verstaan / hij worden blij in zijn moed
# 21439  de keizer van de rooms rijk / en ook mede al de gelijk
# 8559   en komen de koning te gemoet / dat ontmoeten zijn onzoet
# 10795  dat n(prop) varen in zijn land / en stichten n(prop) en brand
# 14137  ik liggen hier al mijn leven lang / in n(prop) aan zijn dank
# 3415   toen de koning dat verstaan / hij worden blij in zijn moed
# 6785   berengarig die dit verstaan / hij worden droef in zijn moed
# 21063  en n(prop) hij hebben verzien / orthen komen meteen
# 7497   roepen zij harde ontfermelijk / o god heer van hemelrijk
# 11165  nu zijn gij ook heer wel kond / doen ik hebben lang staan
# 3031   zijn van de n(prop) 1 stuk / dat hij komen bij geluk
# 21573  en komen met groot partij / op de koning van n(prop)
# 7761   roepen zij harde ontfermelijk / o god heer van hemelrijk
# 12445  die nu zijn in angst groot / en in zorg van de dood
# 6341   en knielen als hij zij zien / en ontbieden hij goed dag
# 10335  wie hij zijn de komen daar / de koningin zeggen openbaar
# 13167  zijn vaart ik laten blijven / en willen gij voort beschrijven
# 163    roepen zij harde ontfermelijk / o god heer van hemelrijk
# 14469  die zij zwaarlijk ontvangen / en slaan n(prop) de koning
# 2907   gloei zeggen sedertmeer / dat men ne mogen geen keer
# 19073  zo lang zo hebben hij rijden / dat hij komen te n(prop)
# 7137   van hoog hebben hij het zwart verheffen / en hebben een slag geven
# 9169   zijn schare en zeggen / gij heer door uw edelheid
# 19259  en zij zijn henen varen / god die moeten zij achterwaren
# 12307  zijn vaart ik laten blijven / en willen gij voort beschrijven
# 14399  wonder horen al te veel / dat met zij gaan al de uit spel
# 14743  die behoeven hier toe raad / gij zeggen wel heer zeggen n(prop)
# 13743  ik het zullen gij houden na mijn macht / en god verlenen ik de kracht
# 21025  die zij zwaarlijk ontvangen / en slaan n(prop) de koning
# 13877  het zwaard heffen hij met beide hand / en het slaan tot de tand
# 13831  die jegen n(prop) komen / en slaan de ridder lofzaam
# 3345   dat de stad zijn beliggen / ne weten hij in welk weg
# 17188  ik liggen hier al mijn leven lang / in n(prop) aan zijn dank
# 9841   en slaan n(prop) op de helm boven / ik wanen niet hij ne hebben kloven
# 6921   en eerst het dat zij de keizer zien / ontbieden zijn hij goed dag
# 7559   het zwaard heffen hij met beide hand / en het slaan tot de tand
# 14573  hij de ander hebben verliezen / dat zij hebben rouw en toorn
# 18546  en zijn te haar heer komen / n(prop) die zij hebben vernemen
# 13985  die jegen n(prop) komen / en slaan de ridder lofzaam
# 8009   bidden ik gij uitermate zeer / dat gij bidden willen n(prop)
#
#          title1                  title2 intertext1 intertext2  distance
# 3335   Limborch  Roman der Lorreinen II  None       None       0.031936
# 6723   Limborch  Roman der Lorreinen II  None       None       0.031936
